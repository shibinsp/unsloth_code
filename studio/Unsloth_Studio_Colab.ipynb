# %% [markdown]
# <a href="https://colab.research.google.com/github/shibinsp/unsloth_code/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1484, done.
# remote: Counting objects: 100% (1484/1484), done.
# remote: Compressing objects: 100% (1283/1283), done.
# remote: Total 1484 (delta 197), reused 1036 (delta 177), pack-reused 0 (from 0)
# Receiving objects: 100% (1484/1484), 36.62 MiB | 25.30 MiB/s, done.
# Resolving deltas: 100% (197/197), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  upgrading npm...
#   node           v20.19.0 | npm 11.15.0
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
# ...

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-05-22 09:48:12 [info     ] 🦥 Starting Unsloth Studio...
# 2026-05-22 09:48:12 [info     ]    Loading backend...
# 2026-05-22 09:48:12 [info     ]    Starting server...
# INFO:     Started server process [1623]
# INFO:     Waiting for application startup.
# Hardware detected: CUDA -- Tesla T4
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://34.118.240.175:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# ...
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ...
#
# {"timestamp": "2026-05-22T09:48:18.864469Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
# ...

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-05-22T10:01:06.929024Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 7.8}
# ===
